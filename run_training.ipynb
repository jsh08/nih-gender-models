# %%
# %cd reproduce-chexnet
# Out:
# /home/jupyter/reproduce-chexnet

# %%
#mtrain,ftest
import torch
torch.cuda.empty_cache()
# !python retrain.py
# Out:
# Available GPU count:1
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/transforms.py:219: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# Epoch 1/100
# ----------
# train epoch 1:loss 0.1614 with data size 78468
# val epoch 1:loss 0.1524 with data size 11219
# saving
# Epoch 2/100
# ----------
# train epoch 2:loss 0.1505 with data size 78468
# val epoch 2:loss 0.1497 with data size 11219
# saving
# Epoch 3/100
# ----------
# train epoch 3:loss 0.1462 with data size 78468
# val epoch 3:loss 0.1480 with data size 11219
# saving
# Epoch 4/100
# ----------
# train epoch 4:loss 0.1431 with data size 78468
# val epoch 4:loss 0.1478 with data size 11219
# saving
# Epoch 5/100
# ----------
# train epoch 5:loss 0.1406 with data size 78468
# val epoch 5:loss 0.1478 with data size 11219
# saving
# Epoch 6/100
# ----------
# ...
